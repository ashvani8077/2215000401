# %% [markdown]
# <a href="https://colab.research.google.com/github/ashvani8077/Soft-Computing-Lab/blob/main/Perceptron_OR_Gate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
input=[
    [0,0],
    [0,1],
    [1,0],
    [1,1]
]
expected_output=[0,1,1,1]

# %%
#w1, w2, w3
w1=1
w2=1
b=-0.5

# %%
#activation function
def activation_function(value):
  if value>0:
    return 1
  else:
    return 0

# %%
print("Or GATE using Perceptron \n")
for i in range(len(inputs)):
  x1,x2=inputs[i]
  net_input=(w1*x1)+(w2*x2)+b
  output=activation_function(net_input)
  print("Input: {x1}, {x2} -> Output: {output}")
# Out:
# Or GATE using Perceptron
#
# Input: {x1}, {x2} -> Output: {output}
# Input: {x1}, {x2} -> Output: {output}
# Input: {x1}, {x2} -> Output: {output}
# Input: {x1}, {x2} -> Output: {output}
