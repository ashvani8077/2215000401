# %% [markdown]
# <a href="https://colab.research.google.com/github/ashvani8077/2215000401/blob/main/Linear_Activation_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def linear(x):
  return x

# %%
linear(300)
# Out:
# 300

# %%
linear(-2)
# Out:
# -2
